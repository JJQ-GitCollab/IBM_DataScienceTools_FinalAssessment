# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# __Objectives__
# * List the tasks that a data scientist needs to perform
# * Identify the criteria for determining which language to learn and list the roles involved in data science
# * Explain what R is, list R capabilities, describe the RStudio environment, and list R libraries for Data Science

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java
# 4. Scala
# 5. Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. ggplot2
# 3. NumPy
# 4. Matplotlib

# %% [markdown]
# |Data Science Tools|
# |----|
# |Jupyter Notebook|
# |RStudio|
# |Apache Spark|
# |GitHub|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This code evaluate the expression (3*4)+5
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Juan Quijano
